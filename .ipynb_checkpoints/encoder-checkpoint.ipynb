# %%
import os
import glob
import random
import time
from utils import mfccs_and_spec
import torch
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from random import shuffle
from hparam import hparam as hp
from torch.functional import F
import torch.nn as nn
from torch.utils.data import Dataset
from torch.autograd import Variable, Function
import torch.optim as optim
from data_load import TripletSpeakerDataset
from speech_embedder_net import SpeechEmbedder, GE2ELoss, get_centroids, get_cossim
# Out:
# /home/dexter/Desktop/projects/Voice-Cloning/hparam.py:11: YAMLLoadWarning: calling yaml.load_all() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   for doc in docs:

# %%
import librosa 
import librosa.display
import IPython
import pickle 
import numpy as np
import scipy 
import tensorflow as tf 
from sklearn.externals import joblib
from tensorflow.python.client import device_lib
from keras.layers import Dense, Dropout, BatchNormalization
from keras.models import Sequential
from keras import backend as K
from keras.optimizers import Adam
from tensorflow.saved_model import simple_save
# Out:
# Using TensorFlow backend.

# %%
from utils import mfcc_for_accent
from data_preprocess import get_spectrogram_tisv

# %%
#file_name = "/home/dexter/Desktop/projects/Mini/data/VCTK-Corpus/wav48_silence_trimmed/p225/p225_001_mic2.flac"

# %%
config = tf.ConfigProto(allow_soft_placement = True,
                        device_count = {'CPU' : 6,
                                       'GPU' : 0})

# %%
session = tf.Session(config=config)
K.set_session(session)

# %%
def make_accent_model():
    model = Sequential()

    model.add(Dense(50, input_shape = (14976,), activation = 'relu',name='input'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Dense(75, activation = 'tanh', name='h1'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Dense(100,  activation = 'tanh',name = 'h2'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Dense(100,  activation = 'tanh', name = 'h3'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Dense(100,  activation = 'tanh', name = 'h4'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Dense(100,  activation = 'tanh', name = 'h5'))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))

    model.add(Dense(100,  activation = 'tanh', name ='h6'))
    model.add(BatchNormalization())

    model.add(Dense(3,  activation = 'softmax', name = 'output'))
    return model

# %%
##Mel spectrograms and MFCCs for Indians 
def get_accent_mfccs(path):
    x, _ = librosa.load(path)
    x, mf = mfcc_for_accent(x)
    mf = mf.flatten()
    #print(type(x))
    # l.append(librosa.feature.mfcc(x, sr=f))
    
    dat = np.reshape(mf, (1,mf.shape[0]))
    return x, dat

# %%
embedder_net = SpeechEmbedder().to('cpu')
embedder_net.load_state_dict(torch.load(hp.model.model_path))
accent_net = make_accent_model()
accent_net.load_weights('accent_block_with_scottish.h5')
accent_net.pop()


#wav, sr = librosa.load(file_name)

def run_speaker_encoder(mfccs, embedder_net):
    mel_db = np.transpose(mfccs, axes = (0,2,1))
    mel_db = torch.from_numpy(mel_db)
    #print(mel_db.shape)
    out = embedder_net(mel_db.to('cpu'))
    return out
# Out:
# WARNING:tensorflow:From /home/dexter/anaconda3/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
def get_both_embs(path):
        #for path in enumerate(train_dataset):
        _, accent_mfccs = get_accent_mfccs(path)
        speaker_mfccs = get_spectrogram_tisv(path)
        #print(accent_mfccs.shape)
        #print(speaker_mfccs.shape)
        speaker_emb = run_speaker_encoder(speaker_mfccs, embedder_net)
        #print(speaker_emb.shape)
        accent_emb = accent_net.predict(accent_mfccs)
        #print(accent_emb.shape)
        return speaker_emb, accent_emb

# %%
#sp, ac = get_both_embs(file_name)

# %%
dataset = TripletSpeakerDataset()
data_loader = torch.utils.data.DataLoader(dataset, drop_last=True)

# %%
for batch_idx, (anchor_utter_path, positive_utter_path, negative_utter_path, accent_negative_path, speaker_positive_id, speaker_negative_id, speaker_anchor_id, positive_accent, negative_accent) in enumerate(data_loader):
    print(anchor_utter_path, positive_utter_path, negative_utter_path, accent_negative_path, speaker_positive_id, speaker_negative_id, speaker_anchor_id, positive_accent, negative_accent)
# Out:
# ('data/Scottish/p249/p249_286_mic2.flac',) ('data/Scottish/p249/p249_064_mic1.flac',) ('data/Scottish/p284/p284_273_mic2.flac',) ('data/Indian/p251/p251_105_mic1.flac',) ('p249',) ('p284',) ('p249',) ('Scottish',) ('Indian',)
# ('data/Scottish/p249/p249_105_mic2.flac',) ('data/Scottish/p249/p249_256_mic2.flac',) ('data/Scottish/p284/p284_196_mic2.flac',) ('data/American/p299/p299_345_mic2.flac',) ('p249',) ('p284',) ('p249',) ('Scottish',) ('American',)
# ('data/Irish/p245/p245_114_mic2.flac',) ('data/Irish/p245/p245_297_mic2.flac',) ('data/Irish/p298/p298_236_mic2.flac',) ('data/Scottish/p249/p249_127_mic1.flac',) ('p245',) ('p298',) ('p245',) ('Irish',) ('Scottish',)
# ('data/Scottish/p237/p237_019_mic1.flac',) ('data/Scottish/p237/p237_186_mic1.flac',) ('data/Scottish/p249/p249_159_mic1.flac',) ('data/American/p300/p300_288_mic1.flac',) ('p237',) ('p249',) ('p237',) ('Scottish',) ('American',)
# ('data/American/p301/p301_276_mic2.flac',) ('data/American/p301/p301_269_mic2.flac',) ('data/American/p300/p300_168_mic1.flac',) ('data/Irish/p295/p295_045_mic1.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Irish',)
# ('data/American/p300/p300_062_mic1.flac',) ('data/American/p300/p300_028_mic2.flac',) ('data/American/p301/p301_086_mic2.flac',) ('data/Indian/p376/p376_416_mic1.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Indian',)
# ('data/American/p300/p300_162_mic2.flac',) ('data/American/p300/p300_056_mic2.flac',) ('data/American/p299/p299_168_mic1.flac',) ('data/Irish/p283/p283_045_mic2.flac',) ('p300',) ('p299',) ('p300',) ('American',) ('Irish',)
# ('data/Indian/p248/p248_042_mic1.flac',) ('data/Indian/p248/p248_170_mic1.flac',) ('data/Indian/p251/p251_033_mic2.flac',) ('data/Irish/p245/p245_091_mic1.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('Irish',)
# ('data/Irish/p298/p298_003_mic1.flac',) ('data/Irish/p298/p298_088_mic2.flac',) ('data/Irish/p283/p283_185_mic1.flac',) ('data/Scottish/p234/p234_202_mic1.flac',) ('p298',) ('p283',) ('p298',) ('Irish',) ('Scottish',)
# ('data/Scottish/p237/p237_064_mic2.flac',) ('data/Scottish/p237/p237_318_mic1.flac',) ('data/Scottish/p234/p234_022_mic2.flac',) ('data/American/p299/p299_390_mic1.flac',) ('p237',) ('p234',) ('p237',) ('Scottish',) ('American',)
# ('data/Indian/p248/p248_144_mic2.flac',) ('data/Indian/p248/p248_109_mic2.flac',) ('data/Indian/p251/p251_252_mic1.flac',) ('data/Irish/p283/p283_387_mic1.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('Irish',)
# ('data/Indian/p376/p376_140_mic2.flac',) ('data/Indian/p376/p376_102_mic1.flac',) ('data/Indian/p251/p251_285_mic2.flac',) ('data/American/p301/p301_256_mic2.flac',) ('p376',) ('p251',) ('p376',) ('Indian',) ('American',)
# ('data/American/p300/p300_202_mic2.flac',) ('data/American/p300/p300_157_mic1.flac',) ('data/American/p299/p299_097_mic2.flac',) ('data/Scottish/p284/p284_062_mic1.flac',) ('p300',) ('p299',) ('p300',) ('American',) ('Scottish',)
# ('data/Irish/p298/p298_022_mic1.flac',) ('data/Irish/p298/p298_272_mic2.flac',) ('data/Irish/p283/p283_279_mic1.flac',) ('data/Scottish/p237/p237_250_mic1.flac',) ('p298',) ('p283',) ('p298',) ('Irish',) ('Scottish',)
# ('data/Indian/p248/p248_072_mic1.flac',) ('data/Indian/p248/p248_270_mic2.flac',) ('data/Indian/p251/p251_126_mic1.flac',) ('data/Scottish/p284/p284_087_mic2.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('
mic1.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Scottish',)
# ('data/American/p299/p299_122_mic1.flac',) ('data/American/p299/p299_397_mic1.flac',) ('data/American/p300/p300_073_mic1.flac',) ('data/Scottish/p249/p249_069_mic1.flac',) ('p299',) ('p300',) ('p299',) ('American',) ('Scottish',)
# ('data/Irish/p295/p295_073_mic2.flac',) ('data/Irish/p295/p295_356_mic2.flac',) ('data/Irish/p245/p245_174_mic2.flac',) ('data/Indian/p251/p251_064_mic2.flac',) ('p295',) ('p245',) ('p295',) ('Irish',) ('Indian',)
# ('data/Irish/p295/p295_101_mic2.flac',) ('data/Irish/p295/p295_290_mic1.flac',) ('data/Irish/p283/p283_443_mic2.flac',) ('data/Indian/p248/p248_026_mic2.flac',) ('p295',) ('p283',) ('p295',) ('Irish',) ('Indian',)
# ('data/Indian/p376/p376_205_mic2.flac',) ('data/Indian/p376/p376_133_mic2.flac',) ('data/Indian/p248/p248_027_mic1.flac',) ('data/American/p300/p300_358_mic1.flac',) ('p376',) ('p248',) ('p376',) ('Indian',) ('American',)
# ('data/American/p299/p299_014_mic1.flac',) ('data/American/p299/p299_299_mic1.flac',) ('data/American/p300/p300_347_mic1.flac',) ('data/Indian/p376/p376_015_mic2.flac',) ('p299',) ('p300',) ('p299',) ('American',) ('Indian',)
# ('data/Irish/p295/p295_253_mic2.flac',) ('data/Irish/p295/p295_353_mic1.flac',) ('data/Irish/p298/p298_287_mic2.flac',) ('data/American/p301/p301_360_mic1.flac',) ('p295',) ('p298',) ('p295',) ('Irish',) ('American',)
# ('data/American/p300/p300_017_mic1.flac',) ('data/American/p300/p300_281_mic1.flac',) ('data/American/p301/p301_375_mic1.flac',) ('data/Indian/p251/p251_089_mic2.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Indian',)
# ('data/Irish/p283/p283_343_mic1.flac',) ('data/Irish/p283/p283_301_mic2.flac',) ('data/Irish/p295/p295_293_mic2.flac',) ('data/Scottish/p234/p234_054_mic2.flac',) ('p283',) ('p295',) ('p283',) ('Irish',) ('Scottish',)
# ('data/American/p301/p301_247_mic1.flac',) ('data/American/p301/p301_203_mic2.flac',) ('data/American/p300/p300_289_mic1.flac',) ('data/Irish/p298/p298_144_mic1.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Irish',)
# ('data/American/p300/p300_306_mic2.flac',) ('data/American/p300/p300_068_mic1.flac',) ('data/American/p301/p301_170_mic1.flac',) ('data/Irish/p283/p283_162_mic1.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Irish',)
# ('data/American/p301/p301_074_mic2.flac',) ('data/American/p301/p301_146_mic1.flac',) ('data/American/p300/p300_088_mic2.flac',) ('data/Scottish/p237/p237_104_mic2.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Scottish',)
# ('data/Indian/p376/p376_132_mic2.flac',) ('data/Indian/p376/p376_324_mic1.flac',) ('data/Indian/p248/p248_205_mic2.flac',) ('data/Irish/p295/p295_160_mic1.flac',) ('p376',) ('p248',) ('p376',) ('Indian',) ('Irish',)
# ('data/Scottish/p284/p284_161_mic1.flac',) ('data/Scottish/p284/p284_120_mic1.flac',) ('data/Scottish/p234/p234_002_mic1.flac',) ('data/American/p299/p299_127_mic2.flac',) ('p284',) ('p234',) ('p284',) ('Scottish',) ('American',)
# ('data/Indian/p376/p376_207_mic1.flac',) ('data/Indian/p376/p376_268_mic1.flac',) ('data/Indian/p251/p251_019_mic2.flac',) ('data/Irish/p283/p283_099_mic2.flac',) ('p376',) ('p251',) ('p376',) ('Indian',) ('Irish',)
# ('data/Indian/p248/p248_082_mic1.flac',) ('data/Indian/p248/p248_196_mic1.flac',) ('data/Indian/p251/p251_336_mic2.flac',) ('data/Irish/p295/p295_209_mic2.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('
mic2.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Scottish',)
# ('data/Irish/p298/p298_066_mic2.flac',) ('data/Irish/p298/p298_044_mic2.flac',) ('data/Irish/p283/p283_297_mic1.flac',) ('data/American/p299/p299_040_mic2.flac',) ('p298',) ('p283',) ('p298',) ('Irish',) ('American',)
# ('data/Scottish/p249/p249_100_mic2.flac',) ('data/Scottish/p249/p249_348_mic2.flac',) ('data/Scottish/p284/p284_109_mic1.flac',) ('data/Indian/p376/p376_202_mic2.flac',) ('p249',) ('p284',) ('p249',) ('Scottish',) ('Indian',)
# ('data/American/p299/p299_036_mic1.flac',) ('data/American/p299/p299_248_mic1.flac',) ('data/American/p301/p301_179_mic2.flac',) ('data/Indian/p376/p376_171_mic2.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Indian',)
# ('data/American/p299/p299_341_mic1.flac',) ('data/American/p299/p299_401_mic2.flac',) ('data/American/p301/p301_221_mic1.flac',) ('data/Scottish/p234/p234_125_mic1.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Scottish',)
# ('data/American/p300/p300_167_mic2.flac',) ('data/American/p300/p300_324_mic2.flac',) ('data/American/p301/p301_190_mic2.flac',) ('data/Indian/p376/p376_098_mic2.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Indian',)
# ('data/American/p301/p301_326_mic1.flac',) ('data/American/p301/p301_340_mic1.flac',) ('data/American/p299/p299_249_mic1.flac',) ('data/Scottish/p284/p284_131_mic2.flac',) ('p301',) ('p299',) ('p301',) ('American',) ('Scottish',)
# ('data/Irish/p298/p298_113_mic1.flac',) ('data/Irish/p298/p298_312_mic1.flac',) ('data/Irish/p245/p245_272_mic2.flac',) ('data/Scottish/p234/p234_069_mic2.flac',) ('p298',) ('p245',) ('p298',) ('Irish',) ('Scottish',)
# ('data/Scottish/p234/p234_306_mic1.flac',) ('data/Scottish/p234/p234_358_mic1.flac',) ('data/Scottish/p237/p237_167_mic2.flac',) ('data/Indian/p248/p248_369_mic2.flac',) ('p234',) ('p237',) ('p234',) ('Scottish',) ('Indian',)
# ('data/American/p300/p300_034_mic2.flac',) ('data/American/p300/p300_150_mic1.flac',) ('data/American/p299/p299_269_mic1.flac',) ('data/Scottish/p249/p249_236_mic1.flac',) ('p300',) ('p299',) ('p300',) ('American',) ('Scottish',)
# ('data/Irish/p298/p298_046_mic1.flac',) ('data/Irish/p298/p298_136_mic2.flac',) ('data/Irish/p245/p245_211_mic2.flac',) ('data/Scottish/p237/p237_039_mic1.flac',) ('p298',) ('p245',) ('p298',) ('Irish',) ('Scottish',)
# ('data/American/p299/p299_058_mic2.flac',) ('data/American/p299/p299_241_mic1.flac',) ('data/American/p300/p300_180_mic1.flac',) ('data/Scottish/p284/p284_096_mic1.flac',) ('p299',) ('p300',) ('p299',) ('American',) ('Scottish',)
# ('data/Indian/p251/p251_112_mic2.flac',) ('data/Indian/p251/p251_124_mic1.flac',) ('data/Indian/p376/p376_186_mic2.flac',) ('data/Scottish/p237/p237_302_mic2.flac',) ('p251',) ('p376',) ('p251',) ('Indian',) ('Scottish',)
# ('data/American/p300/p300_050_mic2.flac',) ('data/American/p300/p300_134_mic2.flac',) ('data/American/p301/p301_051_mic2.flac',) ('data/Irish/p295/p295_127_mic2.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Irish',)
# ('data/Scottish/p234/p234_130_mic1.flac',) ('data/Scottish/p234/p234_219_mic2.flac',) ('data/Scottish/p284/p284_306_mic2.flac',) ('data/Indian/p248/p248_132_mic1.flac',) ('p234',) ('p284',) ('p234',) ('Scottish',) ('Indian',)
# ('data/Irish/p298/p298_046_mic2.flac',) ('data/Irish/p298/p298_102_mic1.flac',) ('data/Irish/p245/p245_001_mic1.flac',) ('data/Indian/p376/p376_081_mic1.flac',) ('p298',) ('p245',) ('p298',) ('Irish',) ('Indian',)
# ('data/American/p301/p301_275_mic2.flac',) ('data/American/p301/p301_251_mic1.flac',) ('data/American/p299/p299_319_mic2.flac',) ('data/Irish/p283/p283_307_mic1.flac',) ('p301',) ('p299',) ('p301',) ('American',) ('
mic2.flac',) ('p376',) ('p248',) ('p376',) ('Indian',) ('Scottish',)
# ('data/Scottish/p234/p234_199_mic2.flac',) ('data/Scottish/p234/p234_317_mic2.flac',) ('data/Scottish/p249/p249_083_mic2.flac',) ('data/Indian/p248/p248_269_mic2.flac',) ('p234',) ('p249',) ('p234',) ('Scottish',) ('Indian',)
# ('data/American/p301/p301_409_mic1.flac',) ('data/American/p301/p301_231_mic1.flac',) ('data/American/p299/p299_226_mic1.flac',) ('data/Indian/p376/p376_205_mic1.flac',) ('p301',) ('p299',) ('p301',) ('American',) ('Indian',)
# ('data/Scottish/p249/p249_289_mic1.flac',) ('data/Scottish/p249/p249_170_mic2.flac',) ('data/Scottish/p237/p237_339_mic2.flac',) ('data/Indian/p251/p251_019_mic1.flac',) ('p249',) ('p237',) ('p249',) ('Scottish',) ('Indian',)
# ('data/Indian/p251/p251_240_mic2.flac',) ('data/Indian/p251/p251_036_mic2.flac',) ('data/Indian/p248/p248_190_mic2.flac',) ('data/American/p299/p299_286_mic2.flac',) ('p251',) ('p248',) ('p251',) ('Indian',) ('American',)
# ('data/Irish/p245/p245_282_mic2.flac',) ('data/Irish/p245/p245_346_mic1.flac',) ('data/Irish/p295/p295_364_mic2.flac',) ('data/Indian/p251/p251_356_mic1.flac',) ('p245',) ('p295',) ('p245',) ('Irish',) ('Indian',)
# ('data/American/p300/p300_317_mic1.flac',) ('data/American/p300/p300_115_mic1.flac',) ('data/American/p301/p301_023_mic1.flac',) ('data/Indian/p248/p248_214_mic1.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Indian',)
# ('data/Scottish/p234/p234_338_mic2.flac',) ('data/Scottish/p234/p234_270_mic1.flac',) ('data/Scottish/p249/p249_004_mic1.flac',) ('data/Indian/p248/p248_050_mic1.flac',) ('p234',) ('p249',) ('p234',) ('Scottish',) ('Indian',)
# ('data/American/p301/p301_204_mic2.flac',) ('data/American/p301/p301_333_mic1.flac',) ('data/American/p300/p300_118_mic2.flac',) ('data/Indian/p251/p251_028_mic1.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Indian',)
# ('data/Scottish/p234/p234_312_mic1.flac',) ('data/Scottish/p234/p234_064_mic2.flac',) ('data/Scottish/p284/p284_302_mic1.flac',) ('data/American/p300/p300_240_mic2.flac',) ('p234',) ('p284',) ('p234',) ('Scottish',) ('American',)
# ('data/Irish/p283/p283_468_mic1.flac',) ('data/Irish/p283/p283_045_mic2.flac',) ('data/Irish/p298/p298_266_mic1.flac',) ('data/Indian/p251/p251_237_mic2.flac',) ('p283',) ('p298',) ('p283',) ('Irish',) ('Indian',)
# ('data/Indian/p248/p248_374_mic1.flac',) ('data/Indian/p248/p248_214_mic2.flac',) ('data/Indian/p251/p251_227_mic2.flac',) ('data/American/p301/p301_368_mic2.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('American',)
# ('data/Scottish/p284/p284_202_mic2.flac',) ('data/Scottish/p284/p284_057_mic2.flac',) ('data/Scottish/p234/p234_098_mic1.flac',) ('data/Irish/p283/p283_016_mic1.flac',) ('p284',) ('p234',) ('p284',) ('Scottish',) ('Irish',)
# ('data/American/p301/p301_198_mic2.flac',) ('data/American/p301/p301_160_mic1.flac',) ('data/American/p300/p300_216_mic1.flac',) ('data/Irish/p298/p298_069_mic2.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Irish',)
# ('data/Indian/p251/p251_012_mic1.flac',) ('data/Indian/p251/p251_254_mic2.flac',) ('data/Indian/p248/p248_127_mic2.flac',) ('data/American/p301/p301_123_mic2.flac',) ('p251',) ('p248',) ('p251',) ('Indian',) ('American',)
# ('data/American/p300/p300_300_mic1.flac',) ('data/American/p300/p300_136_mic2.flac',) ('data/American/p299/p299_399_mic1.flac',) ('data/Scottish/p249/p249_115_mic1.flac',) ('p300',) ('p299',) ('p300',) ('American',) ('Scottish',)
# ('data/Indian/p251/p251_102_mic1.flac',) ('data/Indian/p251/p251_304_mic1.flac',) ('data/Indian/p248/p248_089_mic2.flac',) ('data/Irish/p245/p245_175_mic2.flac',) ('p251',) ('p248',) ('p251',) ('Indian',) ('Irish',)
# ('data/American/p299/p299_219_mic1.flac',) ('data/American/p299/p299_308_mic2.flac',) ('data/American/p301/p301_119_mic2.flac',) ('data/Irish/p283/p283_467_mic1.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('
flac',) ('p284',) ('p249',) ('p284',) ('Scottish',) ('American',)
# ('data/Irish/p295/p295_215_mic2.flac',) ('data/Irish/p295/p295_352_mic2.flac',) ('data/Irish/p283/p283_428_mic1.flac',) ('data/American/p300/p300_296_mic1.flac',) ('p295',) ('p283',) ('p295',) ('Irish',) ('American',)
# ('data/Irish/p283/p283_348_mic1.flac',) ('data/Irish/p283/p283_049_mic2.flac',) ('data/Irish/p245/p245_118_mic1.flac',) ('data/Scottish/p237/p237_127_mic1.flac',) ('p283',) ('p245',) ('p283',) ('Irish',) ('Scottish',)
# ('data/American/p299/p299_301_mic1.flac',) ('data/American/p299/p299_222_mic2.flac',) ('data/American/p301/p301_123_mic2.flac',) ('data/Indian/p376/p376_066_mic2.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Indian',)
# ('data/Indian/p376/p376_033_mic1.flac',) ('data/Indian/p376/p376_134_mic1.flac',) ('data/Indian/p248/p248_082_mic1.flac',) ('data/Scottish/p249/p249_057_mic2.flac',) ('p376',) ('p248',) ('p376',) ('Indian',) ('Scottish',)
# ('data/American/p299/p299_182_mic1.flac',) ('data/American/p299/p299_211_mic1.flac',) ('data/American/p301/p301_366_mic2.flac',) ('data/Indian/p251/p251_173_mic2.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Indian',)
# ('data/Scottish/p284/p284_266_mic2.flac',) ('data/Scottish/p284/p284_318_mic1.flac',) ('data/Scottish/p237/p237_048_mic1.flac',) ('data/American/p300/p300_010_mic2.flac',) ('p284',) ('p237',) ('p284',) ('Scottish',) ('American',)
# ('data/Irish/p245/p245_310_mic1.flac',) ('data/Irish/p245/p245_019_mic2.flac',) ('data/Irish/p298/p298_336_mic1.flac',) ('data/Indian/p376/p376_199_mic1.flac',) ('p245',) ('p298',) ('p245',) ('Irish',) ('Indian',)
# ('data/American/p300/p300_229_mic1.flac',) ('data/American/p300/p300_216_mic2.flac',) ('data/American/p301/p301_010_mic1.flac',) ('data/Irish/p283/p283_278_mic1.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Irish',)
# ('data/Scottish/p237/p237_067_mic1.flac',) ('data/Scottish/p237/p237_199_mic1.flac',) ('data/Scottish/p284/p284_389_mic1.flac',) ('data/Irish/p283/p283_414_mic1.flac',) ('p237',) ('p284',) ('p237',) ('Scottish',) ('Irish',)
# ('data/American/p299/p299_290_mic2.flac',) ('data/American/p299/p299_321_mic1.flac',) ('data/American/p301/p301_335_mic2.flac',) ('data/Scottish/p237/p237_029_mic1.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Scottish',)
# ('data/Indian/p376/p376_292_mic1.flac',) ('data/Indian/p376/p376_236_mic1.flac',) ('data/Indian/p251/p251_224_mic2.flac',) ('data/American/p301/p301_331_mic2.flac',) ('p376',) ('p251',) ('p376',) ('Indian',) ('American',)
# ('data/Irish/p245/p245_143_mic2.flac',) ('data/Irish/p245/p245_293_mic1.flac',) ('data/Irish/p298/p298_389_mic1.flac',) ('data/Scottish/p234/p234_240_mic1.flac',) ('p245',) ('p298',) ('p245',) ('Irish',) ('Scottish',)
# ('data/American/p301/p301_376_mic1.flac',) ('data/American/p301/p301_125_mic1.flac',) ('data/American/p300/p300_313_mic2.flac',) ('data/Irish/p283/p283_107_mic1.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Irish',)
# ('data/Indian/p248/p248_350_mic2.flac',) ('data/Indian/p248/p248_329_mic1.flac',) ('data/Indian/p251/p251_301_mic2.flac',) ('data/American/p301/p301_280_mic1.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('American',)
# ('data/Indian/p251/p251_103_mic2.flac',) ('data/Indian/p251/p251_005_mic1.flac',) ('data/Indian/p248/p248_264_mic1.flac',) ('data/Scottish/p237/p237_314_mic2.flac',) ('p251',) ('p248',) ('p251',) ('Indian',) ('Scottish',)
# ('data/American/p301/p301_240_mic1.flac',) ('data/American/p301/p301_332_mic2.flac',) ('data/American/p300/p300_264_mic1.flac',) ('data/Irish/p283/p283_463_mic2.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Irish',)
# ('data/Scottish/p249/p249_037_mic2.flac',) ('data/Scottish/p249/p249_120_mic1.flac',) ('data/Scottish/p284/p284_150_mic1.flac',) ('data/Indian/p251/p251_311_mic1.flac',) ('p249',) ('p284',) ('p249',) ('Scottish',) ('Indian',)
# ('data/Irish/p283/p283_331_mic1.flac',) ('data/Irish/p283/p283_195_mic2.flac',) ('data/Irish/p295/p295_118_mic2.flac',) ('data/Scottish/p237/p237_017_mic2.flac',) ('p283',) ('p295',) ('p283',) ('Irish',) ('Scottish',)
# ('data/Indian/p251/p251_364_mic2.flac',) ('data/Indian/p251/p251_307_mic1.flac',) ('data/Indian/p376/p376_123_mic1.flac',) ('data/American/p300/p300_006_mic2.flac',) ('p251',) ('p376',) ('p251',) ('Indian',) ('American',)
# ('data/American/p299/p299_262_mic2.flac',) ('data/American/p299/p299_219_mic2.flac',) ('data/American/p301/p301_051_mic2.flac',) ('data/Irish/p295/p295_213_mic2.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Irish',)
# ('data/Scottish/p284/p284_368_mic1.flac',) ('data/Scottish/p284/p284_020_mic1.flac',) ('data/Scottish/p249/p249_199_mic2.flac',) ('data/American/p299/p299_288_mic2.flac',) ('p284',) ('p249',) ('p284',) ('Scottish',) ('American',)
# ('data/Indian/p248/p248_155_mic1.flac',) ('data/Indian/p248/p248_235_mic1.flac',) ('data/Indian/p376/p376_250_mic2.flac',) ('data/Irish/p245/p245_001_mic2.flac',) ('p248',) ('p376',) ('p248',) ('Indian',) ('Irish',)
# ('data/Indian/p248/p248_208_mic2.flac',) ('data/Indian/p248/p248_183_mic2.flac',) ('data/Indian/p376/p376_140_mic1.flac',) ('data/American/p301/p301_186_mic2.flac',) ('p248',) ('p376',) ('p248',) ('Indian',) ('American',)
# ('data/Indian/p251/p251_338_mic1.flac',) ('data/Indian/p251/p251_269_mic1.flac',) ('data/Indian/p248/p248_095_mic1.flac',) ('data/Scottish/p234/p234_331_mic1.flac',) ('p251',) ('p248',) ('p251',) ('Indian',) ('Scottish',)
# ('data/Irish/p245/p245_061_mic2.flac',) ('data/Irish/p245/p245_271_mic2.flac',) ('data/Irish/p283/p283_165_mic1.flac',) ('data/Indian/p251/p251_256_mic1.flac',) ('p245',) ('p283',) ('p245',) ('Irish',) ('Indian',)
# ('data/American/p301/p301_038_mic2.flac',) ('data/American/p301/p301_356_mic2.flac',) ('data/American/p300/p300_133_mic1.flac',) ('data/Scottish/p237/p237_184_mic1.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Scottish',)
# ('data/Indian/p376/p376_424_mic2.flac',) ('data/Indian/p376/p376_029_mic1.flac',) ('data/Indian/p248/p248_057_mic2.flac',) ('data/Irish/p283/p283_103_mic1.flac',) ('p376',) ('p248',) ('p376',) ('Indian',) ('Irish',)
# ('data/Indian/p248/p248_047_mic2.flac',) ('data/Indian/p248/p248_329_mic1.flac',) ('data/Indian/p251/p251_307_mic1.flac',) ('data/Irish/p298/p298_384_mic2.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('Irish',)
# ('data/Scottish/p237/p237_318_mic1.flac',) ('data/Scottish/p237/p237_277_mic2.flac',) ('data/Scottish/p234/p234_017_mic1.flac',) ('data/Indian/p248/p248_362_mic2.flac',) ('p237',) ('p234',) ('p237',) ('Scottish',) ('Indian',)
# ('data/American/p301/p301_356_mic1.flac',) ('data/American/p301/p301_010_mic2.flac',) ('data/American/p299/p299_370_mic2.flac',) ('data/Irish/p245/p245_084_mic1.flac',) ('p301',) ('p299',) ('p301',) ('American',) ('Irish',)
# ('data/Irish/p298/p298_366_mic1.flac',) ('data/Irish/p298/p298_104_mic1.flac',) ('data/Irish/p295/p295_075_mic1.flac',) ('data/American/p300/p300_095_mic1.flac',) ('p298',) ('p295',) ('p298',) ('Irish',) ('American',)
# ('data/American/p299/p299_291_mic1.flac',) ('data/American/p299/p299_230_mic2.flac',) ('data/American/p301/p301_013_mic2.flac',) ('data/Indian/p251/p251_329_mic2.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('
mic2.flac',) ('p251',) ('p376',) ('p251',) ('Indian',) ('Scottish',)
# ('data/Scottish/p237/p237_016_mic1.flac',) ('data/Scottish/p237/p237_316_mic1.flac',) ('data/Scottish/p249/p249_299_mic2.flac',) ('data/American/p300/p300_257_mic1.flac',) ('p237',) ('p249',) ('p237',) ('Scottish',) ('American',)
# ('data/American/p299/p299_094_mic2.flac',) ('data/American/p299/p299_152_mic1.flac',) ('data/American/p301/p301_286_mic1.flac',) ('data/Scottish/p284/p284_094_mic2.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Scottish',)
# ('data/American/p299/p299_208_mic1.flac',) ('data/American/p299/p299_082_mic2.flac',) ('data/American/p301/p301_177_mic1.flac',) ('data/Irish/p295/p295_103_mic1.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Irish',)
# ('data/American/p300/p300_167_mic2.flac',) ('data/American/p300/p300_296_mic1.flac',) ('data/American/p301/p301_281_mic1.flac',) ('data/Irish/p295/p295_423_mic2.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Irish',)
# ('data/Scottish/p234/p234_230_mic1.flac',) ('data/Scottish/p234/p234_162_mic1.flac',) ('data/Scottish/p284/p284_425_mic2.flac',) ('data/Irish/p295/p295_230_mic2.flac',) ('p234',) ('p284',) ('p234',) ('Scottish',) ('Irish',)
# ('data/American/p301/p301_225_mic2.flac',) ('data/American/p301/p301_379_mic1.flac',) ('data/American/p299/p299_077_mic2.flac',) ('data/Indian/p251/p251_034_mic2.flac',) ('p301',) ('p299',) ('p301',) ('American',) ('Indian',)
# ('data/Scottish/p249/p249_332_mic2.flac',) ('data/Scottish/p249/p249_181_mic1.flac',) ('data/Scottish/p284/p284_413_mic2.flac',) ('data/Indian/p251/p251_314_mic2.flac',) ('p249',) ('p284',) ('p249',) ('Scottish',) ('Indian',)
# ('data/Indian/p248/p248_172_mic2.flac',) ('data/Indian/p248/p248_191_mic1.flac',) ('data/Indian/p376/p376_058_mic2.flac',) ('data/American/p301/p301_294_mic2.flac',) ('p248',) ('p376',) ('p248',) ('Indian',) ('American',)
# ('data/Scottish/p237/p237_303_mic1.flac',) ('data/Scottish/p237/p237_164_mic2.flac',) ('data/Scottish/p284/p284_097_mic2.flac',) ('data/Indian/p376/p376_215_mic2.flac',) ('p237',) ('p284',) ('p237',) ('Scottish',) ('Indian',)
# ('data/Irish/p283/p283_256_mic2.flac',) ('data/Irish/p283/p283_460_mic2.flac',) ('data/Irish/p298/p298_188_mic2.flac',) ('data/Indian/p248/p248_259_mic2.flac',) ('p283',) ('p298',) ('p283',) ('Irish',) ('Indian',)
# ('data/American/p299/p299_240_mic1.flac',) ('data/American/p299/p299_359_mic1.flac',) ('data/American/p300/p300_207_mic2.flac',) ('data/Irish/p298/p298_136_mic2.flac',) ('p299',) ('p300',) ('p299',) ('American',) ('Irish',)
# ('data/American/p301/p301_270_mic1.flac',) ('data/American/p301/p301_097_mic2.flac',) ('data/American/p300/p300_287_mic2.flac',) ('data/Indian/p251/p251_133_mic1.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Indian',)
# ('data/Indian/p251/p251_135_mic2.flac',) ('data/Indian/p251/p251_183_mic1.flac',) ('data/Indian/p248/p248_270_mic2.flac',) ('data/Scottish/p284/p284_397_mic2.flac',) ('p251',) ('p248',) ('p251',) ('Indian',) ('Scottish',)
# ('data/American/p300/p300_197_mic2.flac',) ('data/American/p300/p300_064_mic2.flac',) ('data/American/p301/p301_177_mic2.flac',) ('data/Indian/p251/p251_024_mic2.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Indian',)
# ...
# ('data/Irish/p295/p295_419_mic2.flac',) ('data/Irish/p295/p295_349_mic1.flac',) ('data/Irish/p298/p298_320_mic1.flac',) ('data/Scottish/p237/p237_035_mic1.flac',) ('p295',) ('p298',) ('p295',) ('Irish',) ('Scottish',)
# ('data/American/p300/p300_160_mic1.flac',) ('data/American/p300/p300_134_mic2.flac',) ('data/American/p299/p299_173_mic2.flac',) ('data/Irish/p283/p283_084_mic2.flac',) ('p300',) ('p299',) ('p300',) ('American',) ('Irish',)
# ('data/Indian/p248/p248_360_mic1.flac',) ('data/Indian/p248/p248_081_mic1.flac',) ('data/Indian/p376/p376_224_mic1.flac',) ('data/Scottish/p234/p234_079_mic1.flac',) ('p248',) ('p376',) ('p248',) ('Indian',) ('Scottish',)
# ('data/American/p299/p299_311_mic1.flac',) ('data/American/p299/p299_352_mic2.flac',) ('data/American/p300/p300_070_mic1.flac',) ('data/Irish/p295/p295_373_mic2.flac',) ('p299',) ('p300',) ('p299',) ('American',) ('Irish',)
# ('data/Irish/p298/p298_235_mic2.flac',) ('data/Irish/p298/p298_299_mic1.flac',) ('data/Irish/p283/p283_370_mic2.flac',) ('data/Indian/p376/p376_339_mic1.flac',) ('p298',) ('p283',) ('p298',) ('Irish',) ('Indian',)
# ('data/Scottish/p234/p234_262_mic1.flac',) ('data/Scottish/p234/p234_232_mic1.flac',) ('data/Scottish/p284/p284_043_mic1.flac',) ('data/Irish/p283/p283_330_mic1.flac',) ('p234',) ('p284',) ('p234',) ('Scottish',) ('Irish',)
# ('data/American/p301/p301_085_mic2.flac',) ('data/American/p301/p301_325_mic2.flac',) ('data/American/p300/p300_242_mic2.flac',) ('data/Indian/p248/p248_151_mic1.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Indian',)
# ('data/American/p299/p299_394_mic1.flac',) ('data/American/p299/p299_190_mic1.flac',) ('data/American/p301/p301_021_mic1.flac',) ('data/Irish/p245/p245_288_mic1.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Irish',)
# ('data/American/p301/p301_358_mic1.flac',) ('data/American/p301/p301_318_mic2.flac',) ('data/American/p299/p299_181_mic1.flac',) ('data/Irish/p283/p283_438_mic1.flac',) ('p301',) ('p299',) ('p301',) ('American',) ('Irish',)
# ('data/Scottish/p234/p234_053_mic2.flac',) ('data/Scottish/p234/p234_213_mic1.flac',) ('data/Scottish/p284/p284_260_mic1.flac',) ('data/American/p299/p299_006_mic2.flac',) ('p234',) ('p284',) ('p234',) ('Scottish',) ('American',)
# ('data/American/p300/p300_141_mic1.flac',) ('data/American/p300/p300_374_mic2.flac',) ('data/American/p301/p301_239_mic2.flac',) ('data/Indian/p376/p376_281_mic1.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Indian',)
# ('data/Indian/p376/p376_132_mic2.flac',) ('data/Indian/p376/p376_076_mic2.flac',) ('data/Indian/p248/p248_100_mic1.flac',) ('data/Scottish/p284/p284_144_mic2.flac',) ('p376',) ('p248',) ('p376',) ('Indian',) ('Scottish',)
# ('data/Irish/p245/p245_183_mic2.flac',) ('data/Irish/p245/p245_304_mic1.flac',) ('data/Irish/p298/p298_223_mic1.flac',) ('data/Indian/p248/p248_166_mic2.flac',) ('p245',) ('p298',) ('p245',) ('Irish',) ('Indian',)
# ('data/American/p299/p299_095_mic1.flac',) ('data/American/p299/p299_105_mic2.flac',) ('data/American/p301/p301_079_mic2.flac',) ('data/Scottish/p237/p237_233_mic2.flac',) ('p299',) ('p301',) ('p299',) ('American',) ('Scottish',)
# ('data/American/p301/p301_112_mic2.flac',) ('data/American/p301/p301_357_mic2.flac',) ('data/American/p300/p300_085_mic1.flac',) ('data/Scottish/p284/p284_285_mic2.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Scottish',)
# ('data/American/p301/p301_371_mic2.flac',) ('data/American/p301/p301_103_mic2.flac',) ('data/American/p300/p300_211_mic1.flac',) ('data/Scottish/p234/p234_097_mic2.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Scottish',)
# ('data/Scottish/p284/p284_131_mic1.flac',) ('data/Scottish/p284/p284_138_mic2.flac',) ('data/Scottish/p249/p249_079_mic1.flac',) ('data/American/p299/p299_373_mic1.flac',) ('p284',) ('p249',) ('p284',) ('Scottish',) ('American',)
# ('data/American/p301/p301_010_mic1.flac',) ('data/American/p301/p301_168_mic1.flac',) ('data/American/p300/p300_201_mic1.flac',) ('data/Scottish/p284/p284_283_mic2.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Scottish',)
# ('data/Irish/p295/p295_202_mic2.flac',) ('data/Irish/p295/p295_250_mic2.flac',) ('data/Irish/p245/p245_044_mic2.flac',) ('data/Indian/p248/p248_066_mic1.flac',) ('p295',) ('p245',) ('p295',) ('Irish',) ('Indian',)
# ('data/American/p299/p299_321_mic1.flac',) ('data/American/p299/p299_123_mic2.flac',) ('data/American/p300/p300_242_mic1.flac',) ('data/Scottish/p237/p237_082_mic1.flac',) ('p299',) ('p300',) ('p299',) ('American',) ('Scottish',)
# ('data/Indian/p248/p248_120_mic1.flac',) ('data/Indian/p248/p248_124_mic2.flac',) ('data/Indian/p376/p376_031_mic1.flac',) ('data/Scottish/p284/p284_257_mic2.flac',) ('p248',) ('p376',) ('p248',) ('Indian',) ('Scottish',)
# ('data/Scottish/p234/p234_005_mic2.flac',) ('data/Scottish/p234/p234_065_mic2.flac',) ('data/Scottish/p237/p237_131_mic1.flac',) ('data/Irish/p295/p295_352_mic1.flac',) ('p234',) ('p237',) ('p234',) ('Scottish',) ('Irish',)
# ('data/Indian/p248/p248_103_mic2.flac',) ('data/Indian/p248/p248_195_mic2.flac',) ('data/Indian/p251/p251_018_mic2.flac',) ('data/American/p301/p301_251_mic1.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('American',)
# ('data/Irish/p283/p283_425_mic1.flac',) ('data/Irish/p283/p283_376_mic2.flac',) ('data/Irish/p298/p298_299_mic1.flac',) ('data/Scottish/p284/p284_383_mic2.flac',) ('p283',) ('p298',) ('p283',) ('Irish',) ('Scottish',)
# ('data/Indian/p251/p251_323_mic1.flac',) ('data/Indian/p251/p251_221_mic2.flac',) ('data/Indian/p248/p248_032_mic1.flac',) ('data/American/p299/p299_218_mic2.flac',) ('p251',) ('p248',) ('p251',) ('Indian',) ('American',)
# ('data/Irish/p245/p245_118_mic1.flac',) ('data/Irish/p245/p245_287_mic1.flac',) ('data/Irish/p295/p295_416_mic1.flac',) ('data/Scottish/p284/p284_253_mic1.flac',) ('p245',) ('p295',) ('p245',) ('Irish',) ('Scottish',)
# ('data/American/p300/p300_328_mic1.flac',) ('data/American/p300/p300_019_mic1.flac',) ('data/American/p301/p301_296_mic1.flac',) ('data/Scottish/p249/p249_162_mic1.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Scottish',)
# ('data/Scottish/p237/p237_219_mic1.flac',) ('data/Scottish/p237/p237_344_mic1.flac',) ('data/Scottish/p234/p234_347_mic2.flac',) ('data/Irish/p283/p283_189_mic1.flac',) ('p237',) ('p234',) ('p237',) ('Scottish',) ('Irish',)
# ('data/Indian/p248/p248_153_mic1.flac',) ('data/Indian/p248/p248_160_mic1.flac',) ('data/Indian/p376/p376_079_mic1.flac',) ('data/American/p300/p300_383_mic2.flac',) ('p248',) ('p376',) ('p248',) ('Indian',) ('American',)
# ('data/American/p301/p301_331_mic2.flac',) ('data/American/p301/p301_356_mic2.flac',) ('data/American/p300/p300_058_mic2.flac',) ('data/Indian/p251/p251_040_mic2.flac',) ('p301',) ('p300',) ('p301',) ('American',) ('Indian',)
# ('data/Indian/p251/p251_120_mic1.flac',) ('data/Indian/p251/p251_182_mic1.flac',) ('data/Indian/p376/p376_353_mic1.flac',) ('data/American/p299/p299_252_mic1.flac',) ('p251',) ('p376',) ('p251',) ('Indian',) ('American',)
# ('data/Irish/p283/p283_416_mic1.flac',) ('data/Irish/p283/p283_246_mic2.flac',) ('data/Irish/p295/p295_005_mic2.flac',) ('data/Indian/p248/p248_115_mic1.flac',) ('p283',) ('p295',) ('p283',) ('Irish',) ('Indian',)
# ('data/Indian/p376/p376_202_mic1.flac',) ('data/Indian/p376/p376_394_mic2.flac',) ('data/Indian/p251/p251_289_mic1.flac',) ('data/Irish/p283/p283_062_mic1.flac',) ('p376',) ('p251',) ('p376',) ('Indian',) ('Irish',)
# ('data/Scottish/p284/p284_419_mic2.flac',) ('data/Scottish/p284/p284_140_mic1.flac',) ('data/Scottish/p249/p249_068_mic1.flac',) ('data/American/p301/p301_394_mic2.flac',) ('p284',) ('p249',) ('p284',) ('Scottish',) ('American',)
# ('data/American/p300/p300_338_mic1.flac',) ('data/American/p300/p300_389_mic2.flac',) ('data/American/p299/p299_189_mic1.flac',) ('data/Indian/p376/p376_227_mic1.flac',) ('p300',) ('p299',) ('p300',) ('American',) ('Indian',)
# ('data/Scottish/p284/p284_271_mic1.flac',) ('data/Scottish/p284/p284_179_mic2.flac',) ('data/Scottish/p234/p234_317_mic2.flac',) ('data/Irish/p295/p295_095_mic2.flac',) ('p284',) ('p234',) ('p284',) ('Scottish',) ('Irish',)
# ('data/Irish/p295/p295_108_mic2.flac',) ('data/Irish/p295/p295_071_mic1.flac',) ('data/Irish/p283/p283_285_mic2.flac',) ('data/Scottish/p234/p234_319_mic1.flac',) ('p295',) ('p283',) ('p295',) ('Irish',) ('Scottish',)
# ('data/Irish/p298/p298_283_mic1.flac',) ('data/Irish/p298/p298_306_mic2.flac',) ('data/Irish/p245/p245_351_mic1.flac',) ('data/Scottish/p284/p284_275_mic1.flac',) ('p298',) ('p245',) ('p298',) ('Irish',) ('Scottish',)
# ('data/American/p301/p301_015_mic2.flac',) ('data/American/p301/p301_304_mic1.flac',) ('data/American/p299/p299_140_mic2.flac',) ('data/Indian/p251/p251_045_mic1.flac',) ('p301',) ('p299',) ('p301',) ('American',) ('Indian',)
# ('data/Irish/p245/p245_234_mic1.flac',) ('data/Irish/p245/p245_217_mic1.flac',) ('data/Irish/p283/p283_049_mic2.flac',) ('data/American/p299/p299_120_mic1.flac',) ('p245',) ('p283',) ('p245',) ('Irish',) ('American',)
# ('data/Irish/p295/p295_069_mic1.flac',) ('data/Irish/p295/p295_277_mic2.flac',) ('data/Irish/p245/p245_273_mic1.flac',) ('data/Indian/p248/p248_185_mic2.flac',) ('p295',) ('p245',) ('p295',) ('Irish',) ('Indian',)
# ('data/Irish/p295/p295_069_mic2.flac',) ('data/Irish/p295/p295_322_mic2.flac',) ('data/Irish/p298/p298_364_mic1.flac',) ('data/Scottish/p237/p237_245_mic1.flac',) ('p295',) ('p298',) ('p295',) ('Irish',) ('Scottish',)
# ('data/Indian/p248/p248_301_mic1.flac',) ('data/Indian/p248/p248_032_mic1.flac',) ('data/Indian/p251/p251_271_mic2.flac',) ('data/Irish/p298/p298_091_mic1.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('Irish',)
# ('data/Irish/p245/p245_334_mic1.flac',) ('data/Irish/p245/p245_336_mic2.flac',) ('data/Irish/p283/p283_042_mic2.flac',) ('data/American/p301/p301_304_mic1.flac',) ('p245',) ('p283',) ('p245',) ('Irish',) ('American',)
# ('data/Scottish/p249/p249_101_mic2.flac',) ('data/Scottish/p249/p249_121_mic2.flac',) ('data/Scottish/p284/p284_389_mic2.flac',) ('data/American/p300/p300_384_mic1.flac',) ('p249',) ('p284',) ('p249',) ('Scottish',) ('American',)
# ('data/American/p300/p300_093_mic1.flac',) ('data/American/p300/p300_218_mic2.flac',) ('data/American/p301/p301_260_mic1.flac',) ('data/Scottish/p249/p249_070_mic2.flac',) ('p300',) ('p301',) ('p300',) ('American',) ('Scottish',)
# ('data/Scottish/p234/p234_341_mic1.flac',) ('data/Scottish/p234/p234_332_mic1.flac',) ('data/Scottish/p237/p237_227_mic1.flac',) ('data/Indian/p376/p376_266_mic1.flac',) ('p234',) ('p237',) ('p234',) ('Scottish',) ('Indian',)
# ('data/Scottish/p237/p237_108_mic2.flac',) ('data/Scottish/p237/p237_187_mic2.flac',) ('data/Scottish/p249/p249_009_mic2.flac',) ('data/Irish/p298/p298_265_mic2.flac',) ('p237',) ('p249',) ('p237',) ('Scottish',) ('Irish',)
# ('data/Scottish/p234/p234_158_mic2.flac',) ('data/Scottish/p234/p234_001_mic1.flac',) ('data/Scottish/p284/p284_085_mic2.flac',) ('data/Indian/p376/p376_347_mic1.flac',) ('p234',) ('p284',) ('p234',) ('Scottish',) ('Indian',)
# ('data/Scottish/p284/p284_356_mic1.flac',) ('data/Scottish/p284/p284_290_mic1.flac',) ('data/Scottish/p249/p249_202_mic1.flac',) ('data/Indian/p248/p248_279_mic1.flac',) ('p284',) ('p249',) ('p284',) ('Scottish',) ('Indian',)
# ('data/American/p301/p301_054_mic2.flac',) ('data/American/p301/p301_196_mic1.flac',) ('data/American/p299/p299_186_mic1.flac',) ('data/Scottish/p237/p237_178_mic2.flac',) ('p301',) ('p299',) ('p301',) ('American',) ('Scottish',)
# ('data/Scottish/p249/p249_111_mic2.flac',) ('data/Scottish/p249/p249_249_mic1.flac',) ('data/Scottish/p284/p284_048_mic1.flac',) ('data/Indian/p251/p251_039_mic2.flac',) ('p249',) ('p284',) ('p249',) ('Scottish',) ('Indian',)
# ('data/Irish/p283/p283_164_mic1.flac',) ('data/Irish/p283/p283_243_mic1.flac',) ('data/Irish/p245/p245_189_mic2.flac',) ('data/American/p301/p301_084_mic2.flac',) ('p283',) ('p245',) ('p283',) ('Irish',) ('American',)
# ('data/Scottish/p249/p249_047_mic1.flac',) ('data/Scottish/p249/p249_010_mic2.flac',) ('data/Scottish/p284/p284_406_mic2.flac',) ('data/Indian/p251/p251_218_mic1.flac',) ('p249',) ('p284',) ('p249',) ('Scottish',) ('Indian',)
# ('data/Indian/p248/p248_035_mic2.flac',) ('data/Indian/p248/p248_324_mic1.flac',) ('data/Indian/p251/p251_177_mic2.flac',) ('data/American/p301/p301_204_mic1.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('American',)
# ('data/Indian/p248/p248_061_mic2.flac',) ('data/Indian/p248/p248_094_mic2.flac',) ('data/Indian/p251/p251_159_mic1.flac',) ('data/American/p299/p299_256_mic1.flac',) ('p248',) ('p251',) ('p248',) ('Indian',) ('American',)
# ('data/Indian/p251/p251_199_mic1.flac',) ('data/Indian/p251/p251_078_mic1.flac',) ('data/Indian/p376/p376_419_mic2.flac',) ('data/Scottish/p284/p284_354_mic2.flac',) ('p251',) ('p376',) ('p251',) ('Indian',) ('Scottish',)
# ('data/Scottish/p234/p234_145_mic1.flac',) ('data/Scottish/p234/p234_086_mic1.flac',) ('data/Scottish/p237/p237_072_mic2.flac',) ('data/American/p300/p300_377_mic1.flac',) ('p234',) ('p237',) ('p234',) ('Scottish',) ('American',)
# ('data/Indian/p251/p251_369_mic2.flac',) ('data/Indian/p251/p251_295_mic1.flac',) ('data/Indian/p376/p376_021_mic2.flac',) ('data/Irish/p283/p283_006_mic1.flac',) ('p251',) ('p376',) ('p251',) ('Indian',) ('Irish',)
# ('data/Irish/p245/p245_302_mic2.flac',) ('data/Irish/p245/p245_144_mic1.flac',) ('data/Irish/p298/p298_297_mic1.flac',) ('data/American/p301/p301_269_mic1.flac',) ('p245',) ('p298',) ('p245',) ('Irish',) ('American',)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a8ccc025626c> in <module>
# ----> 1 for batch_idx, (anchor_utter_path, positive_utter_path, negative_utter_path, accent_negative_path, speaker_positive_id, speaker_negative_id, speaker_anchor_id, positive_accent, negative_accent) in enumerate(data_loader):
#       2     print(anchor_utter_path, positive_utter_path, negative_utter_path, accent_negative_path, speaker_positive_id, speaker_negative_id, speaker_anchor_id, positive_accent, negative_accent)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/Desktop/projects/Voice-Cloning/data_load.py in __getitem__(self, idx)
#     121         negative_speaker_accent = random.sample(accent_negative_speakers, 1)[0]
#     122
# --> 123         accent_negative_utter = random.sample(os.listdir('data/'+negative_accent+'/'+negative_speaker_accent), 1)[0]
#     124
#     125         negative_speaker = random.sample(accent_positive_speakers, 1)[0]
#
# KeyboardInterrupt:

# %%
speaker_positive_id[0], speaker_negative_id, speaker_anchor_id, positive_accent, negative_accent
# Out:
# ('p245', ('p298',), ('p245',), ('Irish',), ('American',))

# %%
anchor_utter_path, positive_utter_path, negative_utter_path, accent_negative_path
# Out:
# (('data/Irish/p245/p245_302_mic2.flac',),
#  ('data/Irish/p245/p245_144_mic1.flac',),
#  ('data/Irish/p298/p298_297_mic1.flac',),
#  ('data/American/p301/p301_269_mic1.flac',))

# %%
class PairwiseDistance(Function):
    def __init__(self, p):
        super(PairwiseDistance, self).__init__()
        self.norm = p

    def forward(self, x1, x2):
        print("above assert: ",x1, x2)
        assert x1.size() == x2.size()
        eps = 1e-4 / x1.size(1)
        diff = torch.abs(x1 - x2)
        out = torch.pow(diff, self.norm).sum(dim=1)
        return torch.pow(out + eps, 1. / self.norm)

class TripletLoss(Function):
    """
    Triplet loss function.
    """
    def __init__(self, margin=0.2):
        super(TripletLoss, self).__init__()
        self.margin = margin
        self.pdist = PairwiseDistance(2)  # norm 2

    def forward(self, anchor, positive, negative):
        d_p = self.pdist.forward(anchor, positive)
        d_n = self.pdist.forward(anchor, negative)

        dist_hinge = torch.clamp(self.margin + d_p - d_n, min=0.0)
        loss = torch.mean(dist_hinge)
        return loss

# %%
class AutoEncoder(nn.Module):
    def __init__(self):
        super(AutoEncoder, self).__init__()
        self.inp1 = nn.Linear(in_features=256, out_features=100)
        self.inp2 = nn.Linear(in_features=100, out_features=100)
        self.b_n = nn.BatchNorm1d(128)
        
        self.drop_out = nn.Dropout(0.25)
        self.l1 = nn.Linear(200, 128)
        self.l2 = nn.Linear(128,128)
        self.out_acc = nn.Linear(128, 100)
        self.out_speak = nn.Linear(128,256)
        
    def forward(self, speaker_emb, acc_emb):
        x1 = F.relu(self.inp1(speaker_emb))
        
        x2 = F.relu(self.inp2(x1))
        print(x1.shape, x2.shape, speaker_emb.shape, acc_emb.shape)
        out = torch.cat((x1, x2), axis=1)
        out = self.l1(out)
        out = F.relu(out)
        out = F.relu(self.l2(out))
        
        mf_acc = self.out_acc(out)
        mf_sp = self.out_speak(out)
        return F.relu(mf_sp), F.relu(mf_acc)

# %%
def train():
    device = hp.device
    dataset = TripletSpeakerDataset()
    data_loader = torch.utils.data.DataLoader(dataset, drop_last=True)
    ae = AutoEncoder().to('cpu')
    optimizer = optim.Adam(ae.parameters())
    optimizer.zero_grad()
    trip_loss = TripletLoss()
    total_loss = 0
    for epoch in range(20):
        for batch_idx, (anchor_utter_path, positive_utter_path, negative_utter_path, accent_negative_path, speaker_positive_id, speaker_negative_id, speaker_anchor_id, positive_accent, negative_accent) in enumerate(data_loader):
            anchor_utter_path, positive_utter_path, negative_utter_path = anchor_utter_path[0], positive_utter_path[0], negative_utter_path[0]
            accent_negative_path, speaker_positive_id, speaker_negative_id = accent_negative_path[0], speaker_positive_id[0], speaker_negative_id[0]
            speaker_anchor_id, positive_accent, negative_accent = speaker_anchor_id[0], positive_accent[0], negative_accent[0]
            
            try:    
                pre_positive_speaker_embs, pre_positive_accent_embs = get_both_embs(positive_utter_path)
                anchor_speaker_embs, anchor_accent_embs = get_both_embs(anchor_utter_path)
                negative_speaker_embs, _ = get_both_embs(negative_utter_path)
                _, negative_accent_embs = get_both_embs(accent_negative_path)
            except ValueError:
                print("ValueError")
                continue
            positive_speaker_embs, positive_accent_embs = ae.forward(pre_positive_speaker_embs, pre_positive_accent_embs)
            optimizer.zero_grad()
            print(anchor_accent_embs.shape)
            accent_trip_loss = trip_loss.forward(anchor_accent_embs, positive_accent_embs, negative_accent_embs)
            speaker_trip_loss = trip_loss.forward(anchor_speaker_embs, positive_speaker_embs, negative_speaker_embs)
            criterion = accent_trip_loss + speaker_trip_loss
            total_loss += criterion
            
            
            
            criterion.backward()
            optimizer.step()
            if (batch_id + 1) % hp.train.log_interval == 0:
                mesg = "{0}\tEpoch:{1}[{2}/{3}],Iteration:{4}\tLoss:{5:.4f}\t\n".format(time.ctime(), epoch+1,
                        batch_id+1, (len(full_dataset)-split)//hp.train.N, iteration,loss)
                print(mesg)
                if hp.train.log_file is not None:
                    with open(hp.train.log_file,'a') as f:
                        f.write(mesg)
            if hp.train.checkpoint_dir is not None and (epoch + 1) % hp.train.checkpoint_interval == 0:
                embedder_net.eval()
                ckpt_model_filename = "ckpt_epoch_" + str(epoc+1) + "_batch_id_" + str(batch_id+1) + ".pth"
                ckpt_model_path = os.path.join(hp.train.checkpoint_dir, ckpt_model_filename)
                torch.save(embedder_net.state_dict(), ckpt_model_path)
                embedder_net.to(device).train()
        embedder_net.eval()
        save_model_filename = "final_epoch_" + str(epoch + 1) + "_batch_id_" + str(batch_id + 1) + ".model"
        save_model_path = os.path.join(hp.train.checkpoint_dir, save_model_filename)
        torch.save(embedder_net.state_dict(), save_model_path)

        print("\nDone, trained model saved at", save_model_path)

# %%
train()
# Out:
# torch.Size([1, 100]) torch.Size([1, 100]) torch.Size([1, 256]) (1, 100)
# (1, 100)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2da0ffaf5447> in <module>
# ----> 1 train()
#
# <ipython-input-15-e477c5f0aec7> in train()
#      25             optimizer.zero_grad()
#      26             print(anchor_accent_embs.shape)
# ---> 27             accent_trip_loss = trip_loss.forward(anchor_accent_embs, positive_accent_embs, negative_accent_embs)
#      28             speaker_trip_loss = trip_loss.forward(anchor_speaker_embs, positive_speaker_embs, negative_speaker_embs)
#      29             criterion = accent_trip_loss + speaker_trip_loss
#
# <ipython-input-17-923bd1ac3efd> in forward(self, anchor, positive, negative)
#      22
#      23     def forward(self, anchor, positive, negative):
# ---> 24         d_p = self.pdist.forward(anchor, positive)
#      25         d_n = self.pdist.forward(anchor, negative)
#      26
#
# <ipython-input-17-923bd1ac3efd> in forward(self, x1, x2)
#       5
#       6     def forward(self, x1, x2):
# ----> 7         print("above assert: ",x1.size(), x2.size())
#       8         assert x1.size() == x2.size()
#       9         eps = 1e-4 / x1.size(1)
#
# TypeError: 'int' object is not callable

# %%
ae = AutoEncoder().to('cpu')

# %%
optimizer.zero_grad()
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )

# %%
positive_speaker_embs, positive_accent_embs = get_both_embs(positive_utter_path)
# Out:
# start text independent utterance feature extraction
# WARNING:tensorflow:From /home/dexter/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.

# %%
positive_speaker_embs.shape
# Out:
# torch.Size([1, 256])

# %%
positive_accent_embs.shape
# Out:
# (1, 100)

# %%
negative_speaker_embs, _ = get_both_embs(negative_utter_path)
# Out:
# start text independent utterance feature extraction

# %%
import numpy as np
from sklearn.manifold import TSNE

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
tsne = TSNE(verbose=1)

# %%
res = tsne.fit_transform(utters, y = speakers)

# %%
for ele in utts:
    print(ele)

# %%
np_utts = np.asarray(utts, dtype='float32')

# %%
utts = np.load('utterances.npy', allow_pickle=True)
speakers = np.load('speakers.npy', allow_pickle=True)

# %%
embedder_net(j[:,0,...].to('cuda'))

# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_mldata
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
y = np.asarray(speakers)
X = np.squeeze(np.asarray(utters),1)
print(X.shape, y.shape)

# %%
feat_cols = [ 'pixel'+str(i) for i in range(X.shape[1]) ]
df = pd.DataFrame(X,columns=feat_cols)
df['y'] = y
df['label'] = df['y'].apply(lambda i: str(i))
X, y = None, None
print('Size of the dataframe: {}'.format(df.shape))

# %%
# For reproducability of the results
np.random.seed(42)
rndperm = np.random.permutation(df.shape[0])

# %%
N = 10000
df_subset = df.loc[rndperm[:N],:].copy()
data_subset = df_subset[feat_cols].values
pca = PCA(n_components=3)
pca_result = pca.fit_transform(data_subset)
df_subset['pca-one'] = pca_result[:,0]
df_subset['pca-two'] = pca_result[:,1] 
df_subset['pca-three'] = pca_result[:,2]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))

# %%
np.squeeze(utters, axis=1).shape

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=10000)
tsne_results = tsne.fit_transform(pd.DataFrame(np.squeeze(np.asarray(utters),1)))
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))

# %%
df_subset['tsne-2d-one'] = tsne_results[:,0]
df_subset['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue="y",
    palette=sns.color_palette("hls", 168),
    data=df_subset,
    legend="brief",
    alpha=0.3
)

# %%
y

# %%
plt.scatter(tsne_results[:,0], tsne_results[:,1])

# %%
sns.lmplot(x='_wef_',
          y='__ewwf',
          data = tsne_results,
          fit_reg=False,
          legend=True,
          hue='speakers')

# %%
np.unique(y).shape
